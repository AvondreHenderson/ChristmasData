# %% [markdown]
# ## Create a  list of holiday movies and put into PostgreSQL table <br>
# We would like to acknowledge OMDBapi for creation of their comprehensive database and providing an API for accessing it.

# %% [markdown]
# #### Installation of additional libraries (keep commented if already installed):

# %%
# pip install sqlalchemy-utils

# %% [markdown]
# #### Libraries:

# %%
import requests
import json
import pandas as pd
import sqlalchemy as sql
from sqlalchemy_utils import database_exists, create_database
from config import omdbapi_key
from pprint import pprint

# %% [markdown]
# #### Define query string for OMDBapi:

# %%
# API query URL:
base_url = "http://www.omdbapi.com/?apikey=" + omdbapi_key + "&s="
search_term = "christmas"
search_url = base_url + search_term

# %% [markdown]
# #### Send first query to OMDB and check for status:

# %%
# Query API and indicate success or not:
try:
    response = requests.get(search_url)
    print(f"Request status: {response.status_code} {response.reason}")
except:
    print("An error has occured.")
# Out:
# Request status: 200 OK

# %% [markdown]
# #### Convert query response to JSON and inspect how it is organized:

# %%
# Convert the response to JSON, and print the result (do this to see how the OMDB JSON is organized):
try:
    data = response.json()
    pprint(data)
except:
    print("An error has occured")
# Out:
# {'Response': 'True',
#  'Search': [{'Poster': 'https://m.media-amazon.com/images/M/MV5BNWE4OTNiM2ItMjY4Ni00ZTViLWFiZmEtZGEyNGY2ZmNlMzIyXkEyXkFqcGdeQXVyMDU5NDcxNw@@._V1_SX300.jpg',
#              'Title': 'The Nightmare Before Christmas',
#              'Type': 'movie',
#              'Year': '1993',
#              'imdbID': 'tt0107688'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BNWNiNTczNzEtMjQyZC00MjFmLTkzMDMtODk4ZGMyZmE0N2E4XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg',
#              'Title': 'How the Grinch Stole Christmas',
#              'Type': 'movie',
#              'Year': '2000',
#              'imdbID': 'tt0170016'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BMGZkMWQ2MzMtYTkxYS00OThmLWI0ZTQtNmY0ZTkyY2E4MjliXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SX300.jpg',
#              'Title': "National Lampoon's Christmas Vacation",
#              'Type': 'movie',
#              'Year': '1989',
#              'imdbID': 'tt0097958'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BOWMyNjE0MzEtMzVjNy00NjIxLTg0ZjMtMWJhNGI1YmVjYTczL2ltYWdlXkEyXkFqcGdeQXVyNzc5MjA3OA@@._V1_SX300.jpg',
#              'Title': 'A Christmas Story',
#              'Type': 'movie',
#              'Year': '1983',
#              'imdbID': 'tt0085334'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BMTM1MTI5ODU4MV5BMl5BanBnXkFtZTcwNTYyNTU4Mg@@._V1_SX300.jpg',
#              'Title': 'A Christmas Carol',
#              'Type': 'movie',
#              'Year': '2009',
#              'imdbID': 'tt1067106'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BYzgyZjE1MjUtYjFjZS00NzMzLWFmNWMtMDJjNGY0ZTgwYjc3XkEyXkFqcGdeQXVyMjQwMjk0NjI@._V1_SX300.jpg',
#              'Title': 'Office Christmas Party',
#              'Type': 'movie',
#              'Year': '2016',
#              'imdbID': 'tt1711525'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BMzA1NTQzMjAyOV5BMl5BanBnXkFtZTcwNDcyMjY2Ng@@._V1_SX300.jpg',
#              'Title': 'A Very Harold & Kumar 3D Christmas',
#              'Type': 'movie',
#              'Year': '2011',
#              'imdbID': 'tt1268799'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BNTA3NjU3OTM2MV5BMl5BanBnXkFtZTgwNjQ2MzE1NjM@._V1_SX300.jpg',
#              'Title': 'The Christmas Chronicles',
#              'Type': 'movie',
#              'Year': '2018',
#              'imdbID': 'tt2990140'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BNTQ4ZmY0NjgtYzVhNy00NzhiLTk3YTYtNzM1MTdjM2VhZDA3XkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_SX300.jpg',
#              'Title': 'Last Christmas',
#              'Type': 'movie',
#              'Year': '2019',
#              'imdbID': 'tt8623904'},
#             {'Poster': 'https://m.media-amazon.com/images/M/MV5BMmY4Njk5OGQtZGMzYS00NmRhLTgxMzMtYzE0YzE1MDg4NDM1XkEyXkFqcGdeQXVyMTA4NjE0NjEy._V1_SX300.jpg',
#              'Title': 'Arthur Christmas',
#              'Type': 'movie',
#              'Year': '2011',
#              'imdbID': 'tt1430607'}],
#  'totalResults': '4832'}

# %% [markdown]
# #### Put the data from the JSON into lists:

# %%
# Create blank lists to store the results:
imageURLs = []
titles = []
types = []
years = []
imdbIDs = []

# Get the total number of matches in the database:
totalResults = int(data['totalResults'])

# Loop through the results and populate the lists:
for index, movie in enumerate(data['Search']):
    imageURLs.append(data['Search'][index]['Poster'])
    titles.append(data['Search'][index]['Title'])
    types.append(data['Search'][index]['Type'])
    years.append(data['Search'][index]['Year'])
    imdbIDs.append(data['Search'][index]['imdbID'])

# Status message:
if totalResults > 10:
    print("First page of results retrieved.")
    print("Run the next code cell to get the rest.")
else:
    print("All results have been retrieved.")
# Out:
# First page of results retrieved.
# Run the next code cell to get the rest.

# %% [markdown]
# #### Repeat the above processes to retrieve the rest of the movies from OMDB: <br>
# * OMDB only returns 10 movies per request. <br>
# * Multiple queries will be needed to retrieve all the matching movies.

# %%
# Determine the number of pages needed to retrieve all movies:
if (totalResults % 10) > 0:
    totalPages = int(totalResults / 10) + 1
else:
    totalPages = int(totalResults / 10)

# Make successive additional requests to retrieve all the pages of results:
for pageNum in range(2, totalPages+1):
    try:
        response = requests.get(f"{search_url}&page={pageNum}")
        if response.status_code == 200:
            data = response.json()
            for index, movie in enumerate(data['Search']):
                imageURLs.append(data['Search'][index]['Poster'])
                titles.append(data['Search'][index]['Title'])
                types.append(data['Search'][index]['Type'])
                years.append(data['Search'][index]['Year'])
                imdbIDs.append(data['Search'][index]['imdbID'])
            print(f"Page {pageNum} of {totalPages} successfully retrieved.")
        else:
            print("An error has occured.")
            break
    except:
        print("An error has occured.")
        break
# Out:
# Page 2 of 484 successfully retrieved.
# Page 3 of 484 successfully retrieved.
# Page 4 of 484 successfully retrieved.
# Page 5 of 484 successfully retrieved.
# Page 6 of 484 successfully retrieved.
# Page 7 of 484 successfully retrieved.
# Page 8 of 484 successfully retrieved.
# Page 9 of 484 successfully retrieved.
# Page 10 of 484 successfully retrieved.
# Page 11 of 484 successfully retrieved.
# Page 12 of 484 successfully retrieved.
# Page 13 of 484 successfully retrieved.
# Page 14 of 484 successfully retrieved.
# Page 15 of 484 successfully retrieved.
# Page 16 of 484 successfully retrieved.
# Page 17 of 484 successfully retrieved.
# Page 18 of 484 successfully retrieved.
# Page 19 of 484 successfully retrieved.
# Page 20 of 484 successfully retrieved.
# Page 21 of 484 successfully retrieved.
# Page 22 of 484 successfully retrieved.
# Page 23 of 484 successfully retrieved.
# Page 24 of 484 successfully retrieved.
# Page 25 of 484 successfully retrieved.
# Page 26 of 484 successfully retrieved.
# Page 27 of 484 successfully retrieved.
# Page 28 of 484 successfully retrieved.
# Page 29 of 484 successfully retrieved.
# Page 30 of 484 successfully retrieved.
# Page 31 of 484 successfully retrieved.
# Page 32 of 484 successfully retrieved.
# Page 33 of 484 successfully retrieved.
# Page 34 of 484 successfully retrieved.
# Page 35 of 484 successfully retrieved.
# Page 36 of 484 successfully retrieved.
# Page 37 of 484 successfully retrieved.
# Page 38 of 484 successfully retrieved.
# Page 39 of 484 successfully retrieved.
# Page 40 of 484 successfully retrieved.
# Page 41 of 484 successfully retrieved.
# Page 42 of 484 successfully retrieved.
# Page 43 of 484 successfully retrieved.
# Page 44 of 484 successfully retrieved.
# Page 45 of 484 successfully retrieved.
# Page 46 of 484 successfully retrieved.
# Page 47 of 484 successfully retrieved.
# Page 48 of 484 successfully retrieved.
# Page 49 of 484 successfully retrieved.
# Page 50 of 484 successfully retrieved.
# Page 51 of 484 successfully retrieved.
# Page 52 of 484 successfully retrieved.
# Page 53 of 484 successfully retrieved.
# Page 54 of 484 successfully retrieved.
# Page 55 of 484 successfully retrieved.
# Page 56 of 484 successfully retrieved.
# Page 57 of 484 successfully retrieved.
# Page 58 of 484 successfully retrieved.
# Page 59 of 484 successfully retrieved.
# Page 60 of 484 successfully retrieved.
# Page 61 of 484 successfully retrieved.
# Page 62 of 484 successfully retrieved.
# Page 63 of 484 successfully retrieved.
# Page 64 of 484 successfully retrieved.
# Page 65 of 484 successfully retrieved.
# Page 66 of 484 successfully retrieved.
# Page 67 of 484 successfully retrieved.
# Page 68 of 484 successfully retrieved.
# Page 69 of 484 successfully retrieved.
# Page 70 of 484 successfully retrieved.
# Page 71 of 484 successfully retrieved.
# Page 72 of 484 successfully retrieved.
# Page 73 of 484 successfully retrieved.
# Page 74 of 484 successfully retrieved.
# Page 75 of 484 successfully retrieved.
# Page 465 of 484 successfully retrieved.
# Page 466 of 484 successfully retrieved.
# Page 467 of 484 successfully retrieved.
# Page 468 of 484 successfully retrieved.
# Page 469 of 484 successfully retrieved.
# Page 470 of 484 successfully retrieved.
# Page 471 of 484 successfully retrieved.
# Page 472 of 484 successfully retrieved.
# Page 473 of 484 successfully retrieved.
# Page 474 of 484 successfully retrieved.
# Page 475 of 484 successfully retrieved.
# Page 476 of 484 successfully retrieved.
# Page 477 of 484 successfully retrieved.
# Page 478 of 484 successfully retrieved.
# Page 479 of 484 successfully retrieved.
# Page 480 of 484 successfully retrieved.
# Page 481 of 484 successfully retrieved.
# Page 482 of 484 successfully retrieved.
# Page 483 of 484 successfully retrieved.
# Page 484 of 484 successfully retrieved.

# %% [markdown]
# #### Check that all movies were retrieved:

# %%
print(f"{len(titles)} movies were retrieved.")
print(f"The first movie is {titles[0]}.")
print(f"The last movie is {titles[len(titles)-1]}")
# Out:
# 4832 movies were retrieved.
# The first movie is The Nightmare Before Christmas.
# The last movie is Untitled A Christmas Carol Project

# %% [markdown]
# #### Create a dataframe from the movie info lists that were created above:

# %%
moviesDict = {
    "Title": titles,
    "Type": types,
    "Year": years,
    "imdbID": imdbIDs,
    "imageURL": imageURLs
}

moviesDF = pd.DataFrame(moviesDict)
moviesDF.head()
# Out:
#                                    Title   Type  Year     imdbID  \
# 0         The Nightmare Before Christmas  movie  1993  tt0107688
# 1         How the Grinch Stole Christmas  movie  2000  tt0170016
# 2  National Lampoon's Christmas Vacation  movie  1989  tt0097958
# 3                      A Christmas Story  movie  1983  tt0085334
# 4                      A Christmas Carol  movie  2009  tt1067106
#
#                                             imageURL
# 0  https://m.media-amazon.com/images/M/MV5BNWE4OT...
# 1  https://m.media-amazon.com/images/M/MV5BNWNiNT...
# 2  https://m.media-amazon.com/images/M/MV5BMGZkMW...
# 3  https://m.media-amazon.com/images/M/MV5BOWMyNj...
# 4  https://m.media-amazon.com/images/M/MV5BMTM1MT...

# %% [markdown]
# #### Remove rows with duplicate imdbIDs:

# %%
moviesDF = moviesDF.drop_duplicates(subset=["imdbID"])

# %% [markdown]
# #### Convert movies dataframe into PostgreSQL table: <br>
# * Make sure that Postgres is running.
# * If database "ChristmasDB" does not already exist, it gets created. <br>
# * If "christmas_movies" table already exists in "ChristmasDB", it is over-written.

# %%
password = "data21"  # Change this to your password before running!!!

try:
    engine = sql.create_engine(f"postgresql://postgres:{password}@localhost/ChristmasDB")
    print("Connection to PostgreSQL successful.")
    if not database_exists(engine.url):
        create_database(engine.url)
        print("New database created: ChristmasDB")
    else:
        print("Connection to database ChristmasDB successful.")
    try:
        with engine.connect() as cnxn:
            moviesDF.to_sql("christmas_movies", cnxn, if_exists="replace")
            print("Table creation successful.")
    except:
        print("Failed to create table.")
except:
    print("Failed to connect.")
# Out:
# Connection to PostgreSQL successful.
# Connection to database ChristmasDB successful.
# Table creation successful.
