# %%
import pandas as pd

# %%
 # Store filepath in a variable
file_one = "Resources/Sales_November_2019.csv"
file_two = "Resources/Sales_December_2019.csv"

# Read our Data file with the pandas library
file_one_df = pd.read_csv(file_one)
file_two_df = pd.read_csv(file_two)

# %%
file_one_df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   278797            Wired Headphones                1      11.99
# 1   278798        USB-C Charging Cable                2      11.95
# 2   278799    Apple Airpods Headphones                1        150
# 3   278800            27in FHD Monitor                1     149.99
# 4   278801  Bose SoundSport Headphones                1      99.99
#
#          Order Date                      Purchase Address
# 0   11/21/2019 9:54   46 Park St, New York City, NY 10001
# 1  11/17/2019 10:03      962 Hickory St, Austin, TX 73301
# 2  11/19/2019 14:56  464 Cherry St, Los Angeles, CA 90001
# 3  11/25/2019 22:24        649 10th St, Seattle, WA 98101
# 4   11/9/2019 13:56         522 Hill St, Boston, MA 02215

# %%
file_one_df.head()
# Out:
#   Order ID               Product Quantity Ordered Price Each  \
# 0   295665    Macbook Pro Laptop                1       1700
# 1   295666    LG Washing Machine                1        600
# 2   295667  USB-C Charging Cable                1      11.95
# 3   295668      27in FHD Monitor                1     149.99
# 4   295669  USB-C Charging Cable                1      11.95
#
#          Order Date                        Purchase Address
# 0   12/30/2019 0:01  136 Church St, New York City, NY 10001
# 1   12/29/2019 7:03     562 2nd St, New York City, NY 10001
# 2  12/12/2019 18:21    277 Main St, New York City, NY 10001
# 3  12/22/2019 15:13     410 6th St, San Francisco, CA 94016
# 4  12/18/2019 12:38           43 Hill St, Atlanta, GA 30301

# %%
frames = [file_one_df, file_one_df]

result_df = pd.concat(frames)
result_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       278797            Wired Headphones                1      11.99
# 1       278798        USB-C Charging Cable                2      11.95
# 2       278799    Apple Airpods Headphones                1        150
# 3       278800            27in FHD Monitor                1     149.99
# 4       278801  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 17656   295660      AAA Batteries (4-pack)                2       2.99
# 17657   295661        USB-C Charging Cable                1      11.95
# 17658   295662    Lightning Charging Cable                1      14.95
# 17659   295663      AAA Batteries (4-pack)                1       2.99
# 17660   295664                Google Phone                1        600
#
#              Order Date                      Purchase Address
# ...

# %%
 # Sorting the DataFrame
sorted_df = result_df.sort_values("Order Date")
sorted_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 15063   293192       AA Batteries (4-pack)                1       3.84
# 15063   293192       AA Batteries (4-pack)                1       3.84
# 10014   288370          Macbook Pro Laptop                1       1700
# 10014   288370          Macbook Pro Laptop                1       1700
# 5714    284260  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 16771      NaN                         NaN              NaN        NaN
# 16947      NaN                         NaN              NaN        NaN
# 17227      NaN                         NaN              NaN        NaN
# 17464      NaN                         NaN              NaN        NaN
# 17469      NaN                         NaN              NaN        NaN
#
#             Order Date                          Purchase Address
# ...

# %%
#  # Drop all rows with missing information
clean_df = sorted_df.dropna()
clean_df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 15063    293192       AA Batteries (4-pack)                 1        3.84
# 15063    293192       AA Batteries (4-pack)                 1        3.84
# 10014    288370          Macbook Pro Laptop                 1        1700
# 10014    288370          Macbook Pro Laptop                 1        1700
# 5714     284260  Bose SoundSport Headphones                 1       99.99
# ...         ...                         ...               ...         ...
# 6177   Order ID                     Product  Quantity Ordered  Price Each
# 12782  Order ID                     Product  Quantity Ordered  Price Each
# 9945   Order ID                     Product  Quantity Ordered  Price Each
# 15424  Order ID                     Product  Quantity Ordered  Price Each
# 4864   Order ID                     Product  Quantity Ordered  Price Each
#
#             Order Date                          Purchase Address
# ...

# %%
cleaner_df = clean_df[clean_df["Order ID"].str.contains("Order ID")==False]
cleaner_df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 15063   293192       AA Batteries (4-pack)                1       3.84
# 15063   293192       AA Batteries (4-pack)                1       3.84
# 10014   288370          Macbook Pro Laptop                1       1700
# 10014   288370          Macbook Pro Laptop                1       1700
# 5714    284260  Bose SoundSport Headphones                1      99.99
# ...        ...                         ...              ...        ...
# 15550   293658    Lightning Charging Cable                1      14.95
# 5120    283689      AAA Batteries (4-pack)                1       2.99
# 5120    283689      AAA Batteries (4-pack)                1       2.99
# 1244    279982  Bose SoundSport Headphones                1      99.99
# 1244    279982  Bose SoundSport Headphones                1      99.99
#
#             Order Date                          Purchase Address
# ...
